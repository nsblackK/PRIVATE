# %%
import threading
import time



def pay_with():
    print("widrawl")
    inp = input ("enter the amount to widthraw")
    e.set()
    print("Proccessing")
    time.sleep(0.01)
    e.clear()
    print("done")
    
    
def bank_ads():
    e.wait()
    while e.isSet():
        print("advertise")
        print("Loan details")
        print("Insurance Policies")
        print("fd details display")

e = threading.Event()    
t1=threading.Thread(target=pay_with)
t2=threading.Thread(target=bank_ads)
t1.start()
t2.start()
# Out:
# widrawl
# enter the amount to widthraw 55
# Proccessingadvertise
# Loan details
#
# Insurance Policies
# fd details display
# advertise
# Loan details
# Insurance Policies
# fd details display
# advertise
# Loan details
# Insurance Policies
# fd details display
# advertise
# Loan details
# Insurance Policies
# fd details display
# advertise
# Loan details
# Insurance Policies
# fd details display
# advertise
# Loan details
# Insurance Policies
# fd details display
# advertise
# Loan details
# Insurance Policies
# fd details display
# advertise
# Loan details
# Insurance Policies
# fd details display
# advertise
# Loan details
# Insurance Policies
# fd details display
# advertise
# Loan details
# Insurance Policies
# fd details display
# advertise
# Loan details
# Insurance Policies
# fd details display
# advertise
# Loan details
# Insurance Policies
# fd details display
# advertise
# Loan details
# Insurance Policies
# fd details display
# advertise
# Loan details
# ...
