# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('heart.csv')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.sex.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df.cp.unique()
# Out:
# array([3, 2, 1, 0], dtype=int64)

# %%
df.fbs.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df.restecg.unique()
# Out:
# array([0, 1, 2], dtype=int64)

# %%
sns.set_style("darkgrid")
plt.title("cp")

sns.barplot(x=df.cp,y=df.age);

# %%
sns.scatterplot(x=df.trestbps,
                y=df.age,
                hue=df.sex, 
                s=50);

# %%
plt.hist(df.age);

# %%
#plt.figure(figsize=(20,12))

plt.plot(df.groupby('age').chol.agg(['mean']));

# %%
sns.set(font_scale=2)

plt.figure(figsize=(20,12))

plt.title("comparing resting-bp, with thalach w.r.t cholestrol ");



plt.plot(df.groupby('chol').trestbps.agg(['sum']))
plt.plot(df.groupby('chol').thalach.agg(['sum']));
