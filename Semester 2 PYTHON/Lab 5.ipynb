# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/Visualization/Titanic_Desaster/train.csv')
df.head
# Out:
# <bound method NDFrame.head of          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# ...

# %%
df.columns
# Out:
# Index(['beer_servings'], dtype='object')

# %%
df = df.groupby('continent')['continent', 'beer_servings'].mean()
df
# Out:
# <ipython-input-4-0d2686448abe>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df = df.groupby('continent')['continent', 'beer_servings'].mean()
#            beer_servings
# continent
# AF             61.471698
# AS             37.045455
# EU            193.777778
# OC             89.687500
# SA            175.083333

# %%
import pandas as pd
df = pd.read_csv('train.csv')

# %%
#Set PassengerId as the index
df = df.rename(columns={'PassengerId': 'index'})

# %%
df.columns
# Out:
# Index(['index', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
sns.set_style("darkgrid")

# %%
#Create a scatterplot with the Fare payed and the Age, differ the plot color by gender


import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
plt.title("Fare v/s Age")

sns.scatterplot(x=df.Age, 
                y=df.Fare, 
                hue=df.Sex, 
                s=50);

# %%
#How many people survived?
plt.barplot(Survived)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-bd522c4e9968> in <module>
#       1 #How many people survived?
# ----> 2 plt.barplot(Survived)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'barplot'
