# %%
#install.packages("ggpubr",dependencies = T)

# %%
library("ggplot2")
# Out:
# Warning message:
# "package 'ggplot2' was built under R version 3.6.3"

# %%
library("ggpubr")
# Out:
# Warning message:
# "package 'ggpubr' was built under R version 3.6.3"

# %%
my_data <- read.csv(file.choose())
my_data
str(my_data)
summary(my_data)
# Out:
#     No  X1.transaction.date X2.house.age X3.distance.to.the.nearest.MRT.station
# 1    1  2012.917            32.0           84.87882
# 2    2  2012.917            19.5          306.59470
# 3    3  2013.583            13.3          561.98450
# 4    4  2013.500            13.3          561.98450
# 5    5  2012.833             5.0          390.56840
# 6    6  2012.667             7.1         2175.03000
# 7    7  2012.667            34.5          623.47310
# 8    8  2013.417            20.3          287.60250
# 9    9  2013.500            31.7         5512.03800
# 10  10  2013.417            17.9         1783.18000
# 11  11  2013.083            34.8          405.21340
# 12  12  2013.333             6.3           90.45606
# 13  13  2012.917            13.0          492.23130
# 14  14  2012.667            20.4         2469.64500
# 15  15  2013.500            13.2         1164.83800
# 16  16  2013.583            35.7          579.20830
# 17  17  2013.250             0.0          292.99780
# ...

# %%
library(ggpubr)
ggscatter(my_data, x = "X2.house.age", y = "Y.house.price.of.unit.area", 
          add = "reg.line", conf.int = TRUE, 
          cor.coef = TRUE, cor.method = "pearson",
          xlab = "house.age", ylab = "house.price.of.unit.area")
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title
