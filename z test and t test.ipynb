# %%
getwd()
# Out:
# [1] "C:/Users/DELL/sem3 R"

# %%
library(readr)
# Out:
# Warning message:
# "package 'readr' was built under R version 3.6.3"

# %%
Perfume_bottle_1<-read_csv("Perfume bottle 1.csv")
head(Perfume_bottle_1)
Perfume_bottle_1$'Machine 1'
mean(Perfume_bottle_1$'Machine 1')
# Out:
# -- Column specification ------------------------------------------------------------------------------------------------
# cols(
#   `Machine 1` = col_double()
# )
#   Machine 1
# 1 148
# 2 148
# 3 149
# 4 154
# 5 156
# 6 155
#   [1] 148 148 149 154 156 155 151 154 152 156 156 152 156 154 151 155 151 152
#  [19] 154 155 150 152 153 150 152 152 152 151 154 152 156 151 152 155 148 150
#  [37] 155 151 153 152 149 151 151 149 149 151 150 148 152 149 152 155 153 152
#  [55] 155 152 157 150 151 150 152 149 153 154 152 154 149 148 151 149 149 155
#  [73] 156 151 155 152 150 153 156 156 155 153 148 149 148 153 152 152 150 148
#  [91] 149 156 153 150 155 153 149 151 154 152
# [1] 152

# %%
zvalue<-(152-150)/(2/sqrt(100))
zvalue
install.packages("BSDA")
library(BSDA)
z.test(x = Perfume_Bottle_1s$'Machine 1', alternative = "greater", sigma.x=2,mu=150)
q<-seq(-4,4,by=0.1)
q
# Out:
# [1] 10
# Warning message:
# "unable to access index for repository https://cran.r-project.org/src/contrib:
#   cannot open URL 'https://cran.r-project.org/src/contrib/PACKAGES'"Warning message:
# "package 'BSDA' is not available (for R version 3.6.1)"Warning message:
# "unable to access index for repository https://cran.r-project.org/bin/windows/contrib/3.6:
#   cannot open URL 'https://cran.r-project.org/bin/windows/contrib/3.6/PACKAGES'"Loading required package: lattice
# Warning message:
# "package 'lattice' was built under R version 3.6.3"
# Attaching package: 'BSDA'
#
# The following object is masked from 'package:datasets':
#
#     Orange
# Error in z.test(x = Perfume_Bottle_1s$"Machine 1", alternative = "greater", : object 'Perfume_Bottle_1s' not found
# Traceback:
#
# 1. z.test(x = Perfume_Bottle_1s$"Machine 1", alternative = "greater",
#  .     sigma.x = 2, mu = 150)

# %%
q<-seq(-4,4,by=0.1)
dt(q,9)
plot(q,dt(q,19),lty="solid", xlab="t",ylab="f(t)")
lines(q,dt(q,9),lty="dashed")
lines(q,dt(q,4),lty="dotted")
# Out:
#  [1] 0.002346299 0.002754923 0.003238138 0.003809876 0.004486645 0.005287966
#  [7] 0.006236886 0.007360536 0.008690765 0.010264823 0.012126091 0.014324830
# [13] 0.016918931 0.019974592 0.023566890 0.027780121 0.032707817 0.038452289
# [19] 0.045123512 0.052837159 0.061711568 0.071863425 0.083401960 0.096421542
# [25] 0.110992638 0.127151279 0.144887385 0.164132589 0.184748471 0.206516442
# [31] 0.229130733 0.252196066 0.275231524 0.297681800 0.318936410 0.338356623
# [37] 0.355308811 0.369201901 0.379525702 0.385886327 0.388034909 0.385886327
# [43] 0.379525702 0.369201901 0.355308811 0.338356623 0.318936410 0.297681800
# [49] 0.275231524 0.252196066 0.229130733 0.206516442 0.184748471 0.164132589
# [55] 0.144887385 0.127151279 0.110992638 0.096421542 0.083401960 0.071863425
# [61] 0.061711568 0.052837159 0.045123512 0.038452289 0.032707817 0.027780121
# [67] 0.023566890 0.019974592 0.016918931 0.014324830 0.012126091 0.010264823
# ...

# %%
vol<-c(151,153,152,152)
t.test(x=vol,mu=150,conf.level=0.95)
library(visualize)
visualize.t(stat=c(-4.899,4.899),df=3,section="tails")
# Out:
# 	One Sample t-test
#
# data:  vol
# t = 4.899, df = 3, p-value = 0.01628
# alternative hypothesis: true mean is not equal to 150
# 95 percent confidence interval:
#  150.7008 153.2992
# sample estimates:
# mean of x
#       152
# Warning message:
# "package 'visualize' was built under R version 3.6.2"
# Plot with title "Student t Distribution
#  df  =  3  "

# %%
#25 bottles were selected and their variance was 5. Has variance "increased" 
#from the historical 4 variance? (95% confidence level)
