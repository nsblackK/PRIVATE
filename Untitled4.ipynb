# %%
ds<- read.csv("Movie-Rating.csv")
ds
# Out:
#     impact
# 1   pos
# 2   pos
# 3   pos
# 4   pos
# 5   pos
# 6   pos
# 7   pos
# 8   pos
# 9   pos
# 10  pos
# 11  pos
# 12  pos
# 13  pos
# 14  pos
# 15  pos
# 16  pos
# 17  pos
# 18  pos
# 19  pos
# 20  pos
# 21  pos
# 22  pos
# 23  pos
# 24  pos
# 25  pos
# 26  pos
# 27  pos
# 28  pos
# 29  pos
# 30  pos
# ... ...
# 71  neg
# 72  neg
# 73  neg
# 74  neg
# 75  neg
# 76  neg
# 77  neg
# 78  neg
# 79  neg
# 80  neg
# 81  neg
# 82  neg
# 83  neg
# 84  neg
# 85  neg
# 86  neg
# 87  neg
# 88  neg
# 89  neg
# 90  neg
# 91  neg
# 92  neg
# 93  neg
# 94  neg
# 95  neg
# 96  neg
# 97  neg
# 98  neg
# 99  neg
# 100 neg
# ...

# %%
install.packages('tm',dependencies = TRUE)
library('tm')
install.packages('tmap',dependencies = TRUE)
library(tmap)
#tm::tm_map()
# Out:
# Warning message:
# "dependencies 'Rcampdf', 'Rgraphviz', 'Rpoppler', 'tm.lexicon.GeneralInquirer' are not available"also installing the dependencies 'qpdf', 'NLP', 'slam', 'antiword', 'filehash', 'pdftools', 'SnowballC'

# %%
myCorpus<-Corpus(VectorSource(ds$feedback))
myCorpus = tm-map(myCorpus, removePunctuation)
# Out:
# Error in Corpus(VectorSource(ds$feedback)): could not find function "Corpus"
# Traceback:
