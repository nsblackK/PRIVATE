# %%
from tkinter import *
import tkinter as tk
from tkinter import messagebox
from PIL import ImageTk,Image

root = Tk()
canvas = Canvas(root, width = 1366, height = 784)

# BLACK background 
Imagebg = ImageTk.PhotoImage(Image.open("C:\\Users\\DELL\\Downloads\\black.jpg"))
BGImage=Label(root,image=Imagebg).place(x=0,y=0,)
canvas.pack()

#LOGO Image
ImageLogo = ImageTk.PhotoImage(Image.open("C:\\Users\\DELL\\Downloads\\NGAMES.png"))
ImageLg=Label(root,image=ImageLogo,border=0).place(x=250,y=150,)
canvas.pack()

#frame
frame = tk.Frame(root, bg="black")
frame.place(x=752, y=150, height=504, width=550 )
#FRAME TITLE
title = Label(frame, text = "Sign In", fg="white", bg="black", font = ("Calibry Light ", 40))
title.place(x=205,y=80)



#username
username = Label (root, text = "Username ", fg="#3498DB", 
bg="black", font = ("Bebop", 16,)).place(x=880, y=330)
e1 = Entry(root,bg="lightgrey").place(x=880,y=360, width=320,height = 25)

#Password
username = Label (root, text = "Password ", fg="#3498DB", 
bg="black", font = ("Bebop", 16,)).place(x=880, y=410)
e1 = Entry(root,bg="lightgrey").place(x=880,y=440, width=320,height = 25)

def clickLogin():
    messagebox.showinfo("Login Status", "Login Successfull")
     
def clickSignup():
    frame = tk.Frame(root, bg="black")
    frame.place(x=0, y=0, height=2000, width=2000 )

    title = Label(frame, text = "Sign Up", fg="white", bg="black", font = ("Calibry Light ", 40,"bold"))
    title.place(x=100,y=80)
    
    #image
    global ImageLogo
    ImageLogo = ImageTk.PhotoImage(Image.open("C:\\Users\\DELL\\Downloads\\dragon.jpg"))
    ImageLg=Label(root,image=ImageLogo,border=0).place(x=310,y=50,)
    canvas.pack()
    
    #username
    username = Label (frame, text = "Username ", fg="#3498DB", 
    bg="black", font = ("Bebop", 14)).place(x=100, y=200)
    e1 = Entry(root,bg="lightgrey").place(x=100,y=230, width=320,height = 25)

        #Password
    username = Label (root, text = "Password ", fg="#3498DB", 
    bg="black", font = ("Bebop", 14)).place(x=100, y=270)
    e1 = Entry(root,bg="lightgrey").place(x=100,y=300, width=320,height = 25)

        #RE Enter Password
    username = Label (root, text = "Re Enter Password ", fg="#3498DB", 
    bg="black", font = ("Bebop", 14)).place(x=100, y=340)
    e1 = Entry(root,bg="lightgrey").place(x=100,y=370, width=320,height = 25)

         #email
    username = Label (root, text = "email ", fg="#3498DB", 
    bg="black", font = ("Bebop", 14)).place(x=100, y=410)
    e1 = Entry(root,bg="lightgrey").place(x=100,y=440, width=320,height = 25)

        #notyfy me
    cb1=Checkbutton(root,text="Notify me when an update comes",fg="#3498DB",
    bg="black", font = ("Bebop", 14)).place(x=95,y=480)

        #age spinbox
    age = Label (root, text = "Age",fg="#3498DB",bg="black", font = ("Bebop", 14)).place(x=100, y=520)
    sp = Spinbox(root, from_ = 18, to = 85, text = "age").place(x=150, y=525)

    #Signup button
    submitbutton=Button(root, text = "SignUp",fg="#3498DB", 
    bg="black", font = ("Bebop", 20), activebackground = "#1A5276", activeforeground = "white").place(x=100,y=590, width = 200, height = 60)
    
    
    
#login button
submitbutton=Button(root, text = "logIn",fg="#3498DB", 
bg="black", font = ("Bebop", 16,), activebackground = "#1A5276", activeforeground = "white", border=0,
command=clickLogin).place(x=880,y=500, width = 155, height = 50)

#Signup button
submitbutton=Button(root, text = "SignUp",fg="#3498DB", 
bg="black", font = ("Bebop", 16,), activebackground = "#1A5276", activeforeground = "white", border = 0,
command=clickSignup).place(x=1045,y=500, width = 155, height = 50)

#FORGET PASSWORD
forget=Label (root, text = "Forget Password? ", fg="#3498DB", 
bg="black", font = ("Bebop", 10,)).place(x=940, y=560)

#NEED HELP
forget=Label (root, text = "Need Help? ", fg="#3498DB", 
bg="black", font = ("Bebop", 10,)).place(x=1065, y=560)

#CONTACT US
forget=Label (root, text = "Contact Us ", fg="#3498DB", 
bg="black", font = ("Bebop", 10,)).place(x=1010, y=580)

root.mainloop()
