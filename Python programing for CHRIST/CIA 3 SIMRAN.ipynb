# %%
from tkinter import *
import tkinter as tk
from tkinter import messagebox
from PIL import ImageTk,Image

root = Tk()
canvas = Canvas(root, width = 1366, height = 784)

#background image1366 x 784
Imagebg = ImageTk.PhotoImage(Image.open("C:\\Users\\DELL\\Downloads\\water.jpg"))
BGImage=Label(root,image=Imagebg).place(x=0,y=0,)
canvas.pack()

#foreground Image
ImageLogo = ImageTk.PhotoImage(Image.open("C:\\Users\\DELL\\Downloads\\sim-share.png"))
ImageLg=Label(root,image=ImageLogo).place(x=250,y=150,)
canvas.pack()

#frame
frame = tk.Frame(root, bg="white")
frame.place(x=752, y=150, height=504, width=550 )

title = Label(frame, text = "Sign In", fg="#1A5276", bg="white", font = ("Calibry Light ", 40))
title.place(x=205,y=80)



#username
username = Label (root, text = "Username ", fg="#1A5276", 
bg="white", font = ("Bebop", 16,)).place(x=880, y=330)
e1 = Entry(root,bg="lightgrey").place(x=880,y=360, width=320,height = 25)

#Password
username = Label (root, text = "Password ", fg="#1A5276", 
bg="white", font = ("Bebop", 16,)).place(x=880, y=410)
e1 = Entry(root,bg="lightgrey").place(x=880,y=440, width=320,height = 25)

def clickLogin():
    messagebox.showinfo("Hello", "successfull")

def clickSignup():
    messagebox.showinfo("Hello", "Signup page coming up in 3..., 2..., next sem!")


#login button
submitbutton=Button(root, text = "logIn",fg="#1A5276", 
bg="white", font = ("Bebop", 16,), activebackground = "#1A5276", activeforeground = "white",
command=clickLogin).place(x=880,y=500, width = 155, height = 50)

#Signup button
submitbutton=Button(root, text = "SignUp",fg="#1A5276", 
bg="white", font = ("Bebop", 16,), activebackground = "#1A5276", activeforeground = "white",
command=clickSignup).place(x=1045,y=500, width = 155, height = 50)

forget=Label (root, text = "Forget Password? ", fg="#1A5276", 
bg="white", font = ("Bebop", 10,)).place(x=950, y=560)

forget=Label (root, text = "Need Help? ", fg="#1A5276", 
bg="white", font = ("Bebop", 10,)).place(x=1065, y=560)

root.mainloop()
